# %%
import pandas  as pd
import numpy as np 
import Dataloader.predict_DataLoader as predLoad
from importlib import reload

reload(predLoad)
# Out:
# <module 'Dataloader.predict_DataLoader' from '/media/yuhua/1863d8d5-bc6b-4e3e-b4c7-e9e1f87a42a1/KDD/london/Dataloader/predict_DataLoader.py'>

# %%
raw = pd.read_csv("bj_meteorology_2018-04-19-0-2018-04-20-23.csv")

# %%
raw.station_id.unique()
# Out:
# array(['CD1', 'BL0', 'GR4', 'MY7', 'HV1', 'GN3', 'GR9', 'LW2', 'GN0',
#        'KF1', 'CD9', 'CT3', 'CT2', 'BX9', 'BX1', 'TH4', 'ST5', 'RB7',
#        'TD5'], dtype=object)

# %%
raw[raw['station_id']== 'BL0']
# Out:
#           id station_id                 time  PM25_Concentration  \
# 1    2965391        BL0  2018-04-19 00:00:00                 NaN
# 20   2965447        BL0  2018-04-19 01:00:00                37.7
# 39   2965503        BL0  2018-04-19 02:00:00                 NaN
# 58   2965559        BL0  2018-04-19 03:00:00                40.8
# 77   2965615        BL0  2018-04-19 04:00:00                 NaN
# 96   2965671        BL0  2018-04-19 04:00:00                 NaN
# 115  2965727        BL0  2018-04-19 07:00:00                 NaN
# 134  2965783        BL0  2018-04-19 08:00:00                 NaN
# 153  2965839        BL0  2018-04-19 09:00:00                 NaN
# 172  2965895        BL0  2018-04-19 10:00:00                 NaN
# 191  2965951        BL0  2018-04-19 11:00:00                16.8
# 210  2966007        BL0  2018-04-19 12:00:00                15.1
# 229  2966063        BL0  2018-04-19 13:00:00                 NaN
# ...

# %%
data_transformer =predLoad.DataTransformer(path = "bj_meteorology_2018-04-19-0-2018-04-20-23.csv",
                                    use_cuda = True)

# %%
data_transformer.data
# Out:
#                  id                 time  PM25_Concentration  \
# station_id
# CD1         2965390  2018-04-19 00:00:00                38.2
# BL0         2965391  2018-04-19 00:00:00                 0.0
# GR4         2965392  2018-04-19 00:00:00                35.8
# MY7         2965393  2018-04-19 00:00:00                37.6
# HV1         2965394  2018-04-19 00:00:00                39.0
# GN3         2965395  2018-04-19 00:00:00                44.6
# GR9         2965396  2018-04-19 00:00:00                38.7
# LW2         2965397  2018-04-19 00:00:00                45.5
# GN0         2965398  2018-04-19 00:00:00                43.6
# KF1         2965399  2018-04-19 00:00:00                 0.0
# CD9         2965400  2018-04-19 00:00:00                 0.0
# CT3         2965401  2018-04-19 00:00:00                55.0
# CT2         2965402  2018-04-19 00:00:00                39.0
# BX9         2965403  2018-04-19 00:00:00                40.5
# ...

# %%
data_transformer.data.loc['CD1',:]
# Out:
#                  id                 time  PM25_Concentration  \
# station_id
# CD1         2965390  2018-04-19 00:00:00                38.2
# CD1         2965446  2018-04-19 01:00:00                39.7
# CD1         2965502  2018-04-19 02:00:00                40.3
# CD1         2965558  2018-04-19 03:00:00                39.7
# CD1         2965614  2018-04-19 04:00:00                43.8
# CD1         2965670  2018-04-19 04:00:00                43.8
# CD1         2965726  2018-04-19 07:00:00                57.6
# CD1         2965782  2018-04-19 07:00:00                57.6
# CD1         2965838  2018-04-19 09:00:00                49.4
# CD1         2965894  2018-04-19 10:00:00                38.5
# CD1         2965950  2018-04-19 11:00:00                23.0
# CD1         2966006  2018-04-19 12:00:00                16.5
# CD1         2966062  2018-04-19 13:00:00                14.6
# CD1         2966118  2018-04-19 14:00:00                12.0
# ...

# %%
current  = pd.read_csv("bj_meteorology_2018-04-19-0-2018-04-20-23.csv")

# %%
current.sort_values(['station_id','time'])
# Out:
#           id station_id                 time  PM25_Concentration  \
# 1    2965391        BL0  2018-04-19 00:00:00                 NaN
# 20   2965447        BL0  2018-04-19 01:00:00                37.7
# 39   2965503        BL0  2018-04-19 02:00:00                 NaN
# 58   2965559        BL0  2018-04-19 03:00:00                40.8
# 77   2965615        BL0  2018-04-19 04:00:00                 NaN
# 96   2965671        BL0  2018-04-19 04:00:00                 NaN
# 115  2965727        BL0  2018-04-19 07:00:00                 NaN
# 134  2965783        BL0  2018-04-19 08:00:00                 NaN
# 153  2965839        BL0  2018-04-19 09:00:00                 NaN
# 172  2965895        BL0  2018-04-19 10:00:00                 NaN
# 191  2965951        BL0  2018-04-19 11:00:00                16.8
# 210  2966007        BL0  2018-04-19 12:00:00                15.1
# 229  2966063        BL0  2018-04-19 13:00:00                 NaN
# ...

# %%
current.set_index(['station_id'], inplace=True)

# %%
current.loc['CD1',:]
# Out:
#                  id                 time  PM25_Concentration  \
# station_id
# CD1         2965390  2018-04-19 00:00:00                38.2
# CD1         2965446  2018-04-19 01:00:00                39.7
# CD1         2965502  2018-04-19 02:00:00                40.3
# CD1         2965558  2018-04-19 03:00:00                39.7
# CD1         2965614  2018-04-19 04:00:00                43.8
# CD1         2965670  2018-04-19 04:00:00                43.8
# CD1         2965726  2018-04-19 07:00:00                57.6
# CD1         2965782  2018-04-19 07:00:00                57.6
# CD1         2965838  2018-04-19 09:00:00                49.4
# CD1         2965894  2018-04-19 10:00:00                38.5
# CD1         2965950  2018-04-19 11:00:00                23.0
# CD1         2966006  2018-04-19 12:00:00                16.5
# CD1         2966062  2018-04-19 13:00:00                14.6
# CD1         2966118  2018-04-19 14:00:00                12.0
# ...
