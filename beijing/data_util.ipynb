# %%
import numpy as np
import pandas as pd
import datetime

# %% [markdown]
# ## beijing_17_18_aq.csv

# %%
bj_aq_dataset_1 = pd.read_csv("Data/beijing_17_18_aq.csv")
bj_aq_dataset_1['utc_time'] = pd.to_datetime(bj_aq_dataset_1['utc_time'])

bj_aq_dataset_1.shape
# Out:
# (311010, 8)

# %%
bj_aq_dataset_1.head()
# Out:
#          stationId            utc_time  PM2.5   PM10    NO2   CO   O3  SO2
# 0  aotizhongxin_aq 2017-01-01 14:00:00  453.0  467.0  156.0  7.2  3.0  9.0
# 1  aotizhongxin_aq 2017-01-01 15:00:00  417.0  443.0  143.0  6.8  2.0  8.0
# 2  aotizhongxin_aq 2017-01-01 16:00:00  395.0  467.0  141.0  6.9  3.0  8.0
# 3  aotizhongxin_aq 2017-01-01 17:00:00  420.0  484.0  139.0  7.4  3.0  9.0
# 4  aotizhongxin_aq 2017-01-01 18:00:00  453.0  520.0  157.0  7.6  4.0  9.0

# %%
bj_aq_dataset_1.tail()
# Out:
#            stationId            utc_time  PM2.5  PM10  NO2  CO  O3  SO2
# 311005  zhiwuyuan_aq 2018-01-31 11:00:00    NaN   NaN  NaN NaN NaN  NaN
# 311006  zhiwuyuan_aq 2018-01-31 12:00:00    NaN   NaN  NaN NaN NaN  NaN
# 311007  zhiwuyuan_aq 2018-01-31 13:00:00    NaN   NaN  NaN NaN NaN  NaN
# 311008  zhiwuyuan_aq 2018-01-31 14:00:00    NaN   NaN  NaN NaN NaN  NaN
# 311009  zhiwuyuan_aq 2018-01-31 15:00:00    NaN   NaN  NaN NaN NaN  NaN

# %%
bj_aq_dataset_1.corr()
# Out:
#           PM2.5      PM10       NO2        CO        O3       SO2
# PM2.5  1.000000  0.850027  0.558195  0.753246 -0.142547  0.515851
# PM10   0.850027  1.000000  0.399688  0.618041 -0.022765  0.379113
# NO2    0.558195  0.399688  1.000000  0.595542 -0.497505  0.434892
# CO     0.753246  0.618041  0.595542  1.000000 -0.267064  0.448478
# O3    -0.142547 -0.022765 -0.497505 -0.267064  1.000000 -0.147803
# SO2    0.515851  0.379113  0.434892  0.448478 -0.147803  1.000000

# %%
print(bj_aq_dataset_1.stationId.unique())
print(" %d unique stations" %(len(bj_aq_dataset_1.stationId.unique())))
# Out:
# ['aotizhongxin_aq' 'badaling_aq' 'beibuxinqu_aq' 'daxing_aq' 'dingling_aq'
#  'donggaocun_aq' 'dongsi_aq' 'dongsihuan_aq' 'fangshan_aq'
#  'fengtaihuayuan_aq' 'guanyuan_aq' 'gucheng_aq' 'huairou_aq' 'liulihe_aq'
#  'mentougou_aq' 'miyun_aq' 'miyunshuiku_aq' 'nansanhuan_aq'
#  'nongzhanguan_aq' 'pingchang_aq' 'pinggu_aq' 'qianmen_aq' 'shunyi_aq'
#  'tiantan_aq' 'tongzhou_aq' 'wanliu_aq' 'wanshouxigong_aq'
#  'xizhimenbei_aq' 'yanqin_aq' 'yizhuang_aq' 'yongdingmennei_aq'
#  'yongledian_aq' 'yufa_aq' 'yungang_aq' 'zhiwuyuan_aq']
#  35 unique stations

# %% [markdown]
# ## Beijing_historical_meo_grid.csv

# %%
bj_aq_dataset_2 = pd.read_csv("Data/Beijing_historical_meo_grid.csv")
bj_aq_dataset_2['utc_time'] = pd.to_datetime(bj_aq_dataset_2['utc_time'])

# %%
bj_aq_dataset_2.shape
# Out:
# (7034706, 9)

# %%
bj_aq_dataset_2.head()
# Out:
#         stationName  longitude  latitude   utc_time  temperature  pressure  \
# 0  beijing_grid_000      115.0      39.0 2017-01-01        -5.47    984.73
# 1  beijing_grid_001      115.0      39.1 2017-01-01        -5.53    979.33
# 2  beijing_grid_002      115.0      39.2 2017-01-01        -5.70    963.14
# 3  beijing_grid_003      115.0      39.3 2017-01-01        -5.88    946.94
# 4  beijing_grid_004      115.0      39.4 2017-01-01        -5.34    928.80
#
#    humidity  wind_direction  wind_speed/kph
# 0     76.60           53.71            3.53
# 1     75.40           43.59            3.11
# 2     71.80            0.97            2.75
# 3     68.20          327.65            3.84
# 4     58.81          317.85            6.14

# %%
bj_aq_dataset_2.tail()
# Out:
#               stationName  longitude  latitude            utc_time  \
# 7034701  beijing_grid_646      118.0      40.6 2018-03-27 05:00:00
# 7034702  beijing_grid_647      118.0      40.7 2018-03-27 05:00:00
# 7034703  beijing_grid_648      118.0      40.8 2018-03-27 05:00:00
# 7034704  beijing_grid_649      118.0      40.9 2018-03-27 05:00:00
# 7034705  beijing_grid_650      118.0      41.0 2018-03-27 05:00:00
#
#          temperature  pressure  humidity  wind_direction  wind_speed/kph
# 7034701        21.64    943.63     27.87          196.62           14.79
# 7034702        22.58    948.03     24.92          197.92           15.80
# 7034703        22.64    945.85     23.57          206.12           16.94
# 7034704        22.71    943.67     22.23          213.17           18.38
# 7034705        22.73    942.95     21.78          215.27           18.91

# %%
bj_aq_dataset_2.corr()
# Out:
#                    longitude      latitude  temperature  pressure  humidity  \
# longitude       1.000000e+00  5.038237e-18     0.089374  0.524847  0.001065
# latitude        5.038237e-18  1.000000e+00    -0.177230 -0.678949  0.072208
# temperature     8.937398e-02 -1.772305e-01     1.000000  0.085410  0.154080
# pressure        5.248468e-01 -6.789494e-01     0.085410  1.000000 -0.149365
# humidity        1.064501e-03  7.220752e-02     0.154080 -0.149365  1.000000
# wind_direction -5.929571e-02  1.744364e-01    -0.220535 -0.198801 -0.210406
# wind_speed/kph  6.888058e-02 -3.831641e-02     0.034962 -0.009759 -0.307891
#
#                 wind_direction  wind_speed/kph
# longitude            -0.059296        0.068881
# latitude              0.174436       -0.038316
# temperature          -0.220535        0.034962
# pressure             -0.198801       -0.009759
# humidity             -0.210406       -0.307891
# wind_direction        1.000000        0.205548
# ...

# %%
# print(bj_aq_dataset_2.stationName.unique())
print(" %d unique stations" %(len(bj_aq_dataset_2.stationName.unique())))
# Out:
#  651 unique stations

# %% [markdown]
# ## beijing_17_18_meo.csv

# %%
weather = pd.read_csv('Data/beijing_17_18_meo.csv')
weather.shape
# Out:
# (158047, 10)

# %%
weather.head()
# Out:
#    station_id   longitude   latitude             utc_time  temperature  \
# 0  shunyi_meo  116.615278  40.126667  2017-01-30 16:00:00         -1.7
# 1  shunyi_meo  116.615278  40.126667  2017-01-30 17:00:00         -3.5
# 2  shunyi_meo  116.615278  40.126667  2017-01-30 18:00:00         -3.7
# 3  shunyi_meo  116.615278  40.126667  2017-01-30 19:00:00         -3.9
# 4  shunyi_meo  116.615278  40.126667  2017-01-30 20:00:00         -4.1
#
#    pressure  humidity  wind_direction  wind_speed      weather
# 0    1028.7        15           215.0         1.6  Sunny/clear
# 1    1028.4        24            16.0         1.0         Haze
# 2    1028.1        27            32.0         1.1         Haze
# 3    1027.6        27            21.0         0.9         Haze
# 4    1026.7        26            17.0         1.1         Haze

# %%
weather.tail()
# Out:
#             station_id   longitude   latitude            utc_time  \
# 158042  xiayunling_meo  115.740556  39.728611 2018-01-31 11:00:00
# 158043  xiayunling_meo  115.740556  39.728611 2018-01-31 12:00:00
# 158044  xiayunling_meo  115.740556  39.728611 2018-01-31 13:00:00
# 158045  xiayunling_meo  115.740556  39.728611 2018-01-31 14:00:00
# 158046  xiayunling_meo  115.740556  39.728611 2018-01-31 15:00:00
#
#         temperature  pressure  humidity  wind_direction  wind_speed  \
# 158042         -5.0     977.2        32           210.0         0.8
# 158043         -6.4     977.5        36        999017.0         0.0
# 158044         -6.8     977.8        39           182.0         1.3
# 158045         -7.1     977.7        39           170.0         1.5
# 158046         -7.4     977.4        39           137.0         1.0
#
#             weather
# 158042  Sunny/clear
# 158043  Sunny/clear
# 158044  Sunny/clear
# 158045  Sunny/clear
# 158046  Sunny/clear

# %%
print(weather.station_id.unique())
print(" %d unique stations" %(len(weather.station_id.unique())))
# Out:
# ['shunyi_meo' 'hadian_meo' 'yanqing_meo' 'miyun_meo' 'huairou_meo'
#  'shangdianzi_meo' 'pinggu_meo' 'tongzhou_meo' 'chaoyang_meo'
#  'pingchang_meo' 'zhaitang_meo' 'mentougou_meo' 'beijing_meo'
#  'shijingshan_meo' 'fengtai_meo' 'daxing_meo' 'fangshan_meo'
#  'xiayunling_meo']
#  18 unique stations

# %%
weather.loc[weather['station_id'] == 'xiayunling_meo']
# Out:
#             station_id   longitude   latitude            utc_time  \
# 149267  xiayunling_meo  115.740556  39.728611 2017-01-30 16:00:00
# 149268  xiayunling_meo  115.740556  39.728611 2017-01-30 17:00:00
# 149269  xiayunling_meo  115.740556  39.728611 2017-01-30 18:00:00
# 149270  xiayunling_meo  115.740556  39.728611 2017-01-30 19:00:00
# 149271  xiayunling_meo  115.740556  39.728611 2017-01-30 20:00:00
# 149272  xiayunling_meo  115.740556  39.728611 2017-01-30 21:00:00
# 149273  xiayunling_meo  115.740556  39.728611 2017-01-30 22:00:00
# 149274  xiayunling_meo  115.740556  39.728611 2017-01-30 23:00:00
# 149275  xiayunling_meo  115.740556  39.728611 2017-01-31 00:00:00
# 149276  xiayunling_meo  115.740556  39.728611 2017-01-31 01:00:00
# 149277  xiayunling_meo  115.740556  39.728611 2017-01-31 02:00:00
# 149278  xiayunling_meo  115.740556  39.728611 2017-01-31 03:00:00
# 149279  xiayunling_meo  115.740556  39.728611 2017-01-31 04:00:00
# ...

# %%
weather['utc_time'] = pd.to_datetime(weather['utc_time'])

# %%
weather.corr()
# Out:
#                 longitude  latitude  temperature  pressure  humidity  \
# longitude        1.000000  0.470579     0.000148  0.001936 -0.009591
# latitude         0.470579  1.000000    -0.002720 -0.003611 -0.010350
# temperature      0.000148 -0.002720     1.000000  0.999986  0.288608
# pressure         0.001936 -0.003611     0.999986  1.000000  0.288664
# humidity        -0.009591 -0.010350     0.288608  0.288664  1.000000
# wind_direction  -0.001336 -0.032187     0.026185  0.026435  0.004809
# wind_speed      -0.011673 -0.003291     0.516361  0.516334  0.148954
#
#                 wind_direction  wind_speed
# longitude            -0.001336   -0.011673
# latitude             -0.032187   -0.003291
# temperature           0.026185    0.516361
# pressure              0.026435    0.516334
# humidity              0.004809    0.148954
# wind_direction        1.000000    0.050947
# wind_speed            0.050947    1.000000

# %%
# weather['datetime'] = pd.to_datetime(weather['utc_time'])
# weather = weather.rename(columns={'station_id': 'station'}).drop('utc_time', axis=1)
# weather['station_type'] = weather['station'].apply(lambda s: s[s.find('_')+1:])
# weather['station'] = weather['station'].apply(lambda s: s[:s.find('_')])
# weather.set_index(['station', 'datetime'], inplace=True)
# weather.sample(3)

# %% [markdown]
# ## beijing_201802_201803_aq.csv

# %%
bei_02_03 = pd.read_csv('Data/beijing_201802_201803_aq.csv')
bei_02_03.shape
# Out:
# (49420, 8)

# %%
bei_02_03.head()
# Out:
#          stationId             utc_time  PM2.5  PM10   NO2   CO   O3   SO2
# 0  aotizhongxin_aq  2018-01-31 16:00:00   49.0  82.0  90.0  0.9  6.0  10.0
# 1  aotizhongxin_aq  2018-01-31 17:00:00   47.0  80.0  90.0  0.9  5.0  10.0
# 2  aotizhongxin_aq  2018-01-31 18:00:00   46.0  91.0  91.0  1.3  5.0  28.0
# 3  aotizhongxin_aq  2018-01-31 19:00:00   60.0  95.0  85.0  2.0  6.0  38.0
# 4  aotizhongxin_aq  2018-01-31 20:00:00   52.0  91.0  81.0  1.9  5.0  30.0

# %%
bei_02_03.shape
# Out:
# (49420, 8)

# %%
bei_02_03.tail()
# Out:
#           stationId             utc_time  PM2.5  PM10  NO2  CO  O3  SO2
# 49415  zhiwuyuan_aq  2018-03-31 11:00:00    NaN   NaN  NaN NaN NaN  NaN
# 49416  zhiwuyuan_aq  2018-03-31 12:00:00    NaN   NaN  NaN NaN NaN  NaN
# 49417  zhiwuyuan_aq  2018-03-31 13:00:00    NaN   NaN  NaN NaN NaN  NaN
# 49418  zhiwuyuan_aq  2018-03-31 14:00:00    NaN   NaN  NaN NaN NaN  NaN
# 49419  zhiwuyuan_aq  2018-03-31 15:00:00    NaN   NaN  NaN NaN NaN  NaN

# %%
print(bei_02_03.stationId.unique())
print(" %d unique stations" %(len(bei_02_03.stationId.unique())))
# Out:
# ['aotizhongxin_aq' 'badaling_aq' 'beibuxinqu_aq' 'daxing_aq' 'dingling_aq'
#  'donggaocun_aq' 'dongsi_aq' 'dongsihuan_aq' 'fangshan_aq'
#  'fengtaihuayuan_aq' 'guanyuan_aq' 'gucheng_aq' 'huairou_aq' 'liulihe_aq'
#  'mentougou_aq' 'miyun_aq' 'miyunshuiku_aq' 'nansanhuan_aq'
#  'nongzhanguan_aq' 'pingchang_aq' 'pinggu_aq' 'qianmen_aq' 'shunyi_aq'
#  'tiantan_aq' 'tongzhou_aq' 'wanliu_aq' 'wanshouxigong_aq'
#  'xizhimenbei_aq' 'yanqin_aq' 'yizhuang_aq' 'yongdingmennei_aq'
#  'yongledian_aq' 'yufa_aq' 'yungang_aq' 'zhiwuyuan_aq']
#  35 unique stations

# %%
bj_aq_dataset_1.shape
# Out:
# (311010, 8)

# %%
bei_02_03.shape
# Out:
# (49420, 8)

# %%
concat = pd.concat([bj_aq_dataset_1, bei_02_03], ignore_index=True)

# %%
concat.shape
# Out:
# (360430, 8)

# %%
concat = concat.sort_values(by=['stationId','utc_time'])

# %%
concat.to_csv("Data/beijing_2017_1_2018_3_aq.csv",index=False)

# %%
bb = pd.read_csv("Data/beijing/beijing_2017_1_2018_3_aq.csv")

# %%
bb[bb.isnull().any(axis=1)]
bb[bb["PM2.5"].isnull()].shape
# Out:
# (23459, 8)

# %%
bb
# Out:
#               stationId             utc_time  PM2.5   PM10    NO2   CO    O3  \
# 0       aotizhongxin_aq  2017-01-01 14:00:00  453.0  467.0  156.0  7.2   3.0
# 1       aotizhongxin_aq  2017-01-01 15:00:00  417.0  443.0  143.0  6.8   2.0
# 2       aotizhongxin_aq  2017-01-01 16:00:00  395.0  467.0  141.0  6.9   3.0
# 3       aotizhongxin_aq  2017-01-01 17:00:00  420.0  484.0  139.0  7.4   3.0
# 4       aotizhongxin_aq  2017-01-01 18:00:00  453.0  520.0  157.0  7.6   4.0
# 5       aotizhongxin_aq  2017-01-01 19:00:00  429.0    NaN  141.0  6.5   3.0
# 6       aotizhongxin_aq  2017-01-01 20:00:00  211.0    NaN  110.0  3.3   NaN
# 7       aotizhongxin_aq  2017-01-01 21:00:00  116.0    NaN   87.0  2.2   4.0
# 8       aotizhongxin_aq  2017-01-01 22:00:00   51.0    NaN   58.0  1.3  26.0
# 9       aotizhongxin_aq  2017-01-01 23:00:00   38.0    NaN   55.0  1.1  28.0
# 10      aotizhongxin_aq  2017-01-02 00:00:00   21.0    NaN   40.0  0.7  42.0
# ...
